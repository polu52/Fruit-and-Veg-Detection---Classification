# %% [markdown]
# <a href="https://www.kaggle.com/code/hamdipolu/date-fruit-classification?scriptVersionId=201174000" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Date Fruit Classification

# %% [markdown]
# In this project, we will create a classification model using date fruit images labeled its own species, obtained from Kaggle.com.We will use Keras deep learning. Then we will save our model. We will integrate the model into our website that we prepared with Streamlit library. When we give a new date palm image, the model will predict which of the 9 types of dates it belongs to.

# %% [markdown]
# <img src='https://upload.wikimedia.org/wikipedia/commons/4/45/Dates005.jpg'>
#
# <a href='https://www.kaggle.com/datasets/wadhasnalhamdan/date-fruit-image-dataset-in-controlled-environment?select=Sokari' >Click hear to reach datset<a>

# %% [markdown]
# ### Import Dataset

# %%
import cv2
import pandas as pd
import os

import numpy as np 
import pandas as pd

# %%
ls '/kaggle/input/date-fruit-image-dataset-in-controlled-environment'
# Out:
#  Ajwa/     Medjool/  'Nabtat Ali'/   Shaishe/   Sugaey/
#  Galaxy/   Meneifi/   Rutab/         Sokari/

# %%
labels=['Ajwa','Medjool','Nabtat Ali','Shaishe',
        'Sugaey','Galaxy','Meneifi','Rutab','Sokari']
img_path='/kaggle/input/date-fruit-image-dataset-in-controlled-environment/'

# %%
img_list=[]
label_list=[]
for label in labels:
    for img_file in os.listdir(img_path+label):
        img_list.append(img_path+label+'/'+img_file)
        label_list.append(label)

# %%
df=pd.DataFrame({'img':img_list,'label':label_list})

# %%
df.head()
# Out:
#                                                  img label
# 0  /kaggle/input/date-fruit-image-dataset-in-cont...  Ajwa
# 1  /kaggle/input/date-fruit-image-dataset-in-cont...  Ajwa
# 2  /kaggle/input/date-fruit-image-dataset-in-cont...  Ajwa
# 3  /kaggle/input/date-fruit-image-dataset-in-cont...  Ajwa
# 4  /kaggle/input/date-fruit-image-dataset-in-cont...  Ajwa

# %%
df.sample(5)
# Out:
#                                                     img    label
# 1236  /kaggle/input/date-fruit-image-dataset-in-cont...  Meneifi
# 1185  /kaggle/input/date-fruit-image-dataset-in-cont...  Meneifi
# 89    /kaggle/input/date-fruit-image-dataset-in-cont...     Ajwa
# 663   /kaggle/input/date-fruit-image-dataset-in-cont...   Sugaey
# 303   /kaggle/input/date-fruit-image-dataset-in-cont...  Medjool

# %%
df['img'][564]
# Out:
# '/kaggle/input/date-fruit-image-dataset-in-controlled-environment/Shaishe/Shaishe Date (33).JPG'

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

df['encode_label'] = encoder.fit_transform(df['label'])

# %%
df.sample(5)
# Out:
#                                                     img       label  \
# 986   /kaggle/input/date-fruit-image-dataset-in-cont...      Galaxy
# 1299  /kaggle/input/date-fruit-image-dataset-in-cont...       Rutab
# 1058  /kaggle/input/date-fruit-image-dataset-in-cont...     Meneifi
# 612   /kaggle/input/date-fruit-image-dataset-in-cont...     Shaishe
# 413   /kaggle/input/date-fruit-image-dataset-in-cont...  Nabtat Ali
#
#       encode_label
# 986              1
# 1299             5
# 1058             3
# 612              6
# 413              4

# %%
df['label'].value_counts()
# Out:
# label
# Sokari        264
# Meneifi       232
# Galaxy        190
# Nabtat Ali    177
# Ajwa          175
# Shaishe       171
# Sugaey        168
# Rutab         146
# Medjool       135
# Name: count, dtype: int64

# %%
df['encode_label'].value_counts()
# Out:
# encode_label
# 7    264
# 3    232
# 1    190
# 4    177
# 0    175
# 6    171
# 8    168
# 5    146
# 2    135
# Name: count, dtype: int64

# %% [markdown]
# ### Deep Learning

# %% [markdown]
# We will identify x and y datas.

# %%
x=[]
for img in df['img']:
    img=cv2.imread(img)
    img=cv2.resize(img,(170,170)) #We resized the image to 170x170 pixels.
    img=img/255.0 #normalize the data
    x.append(img)

# %%
x=np.array(x)

# %%
y=df['encode_label']

# %% [markdown]
# Let's import train test split and we will split%20 of our datas as test data.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# CNN - Convolutional Neural Networks

# %%
from keras.models import Sequential
from keras.layers import Conv2D, Dense, Flatten, Input, MaxPooling2D,Dropout,BatchNormalization,Reshape

# %%
model = Sequential()
model.add(Input(shape=(170,170,3)))
model.add(Conv2D(32,(3,3),activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(128))
model.add(Dense(9,activation='softmax'))
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,epochs=12,validation_data=(x_test,y_test),verbose=1)
# Out:
# Epoch 1/12
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728944572.571494      71 service.cc:145] XLA service 0x7c5114005f90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1728944572.571572      71 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1728944572.571577      71 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
#  7/42 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.1422 - loss: 16.6938
# I0000 00:00:1728944576.558194      71 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - accuracy: 0.2188 - loss: 8.7149 - val_accuracy: 0.6205 - val_loss: 1.2198
# Epoch 2/12
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.6397 - loss: 1.0664 - val_accuracy: 0.7289 - val_loss: 0.7523
# ...

# %%
model.save('date_fruit_model6.h5')

# %% [markdown]
# We trained our model and achieved a 96% accuracy score. We saved our model, and now we can use it in any algorithm.

# %% [markdown]
# ## Transfer Learning

# %% [markdown]
# We trained a new model from scratch using CNN. However, we can also achieve our goal by using pre-trained models and providing them with our own data. Among the pre-trained models, the most widely used in the field of image processing are the ResNet50 and VGG16 models. Here, we will use the VGG16 model.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, Dense, Flatten, Input, MaxPooling2D,Dropout,BatchNormalization,Reshape
from tensorflow.keras.applications import VGG16,ResNet50
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
data_dir='/kaggle/input/date-fruit-image-dataset-in-controlled-environment/'
img_width,img_heigth=32,32

train_datagen=ImageDataGenerator(rescale=1/255, validation_split=.20)

train_datagenerator=train_datagen.flow_from_directory(directory=data_dir,target_size=(img_width,img_heigth),
                                class_mode='categorical', subset='training')

test_datagen=ImageDataGenerator(rescale=1/255)
test_datagenerator=train_datagen.flow_from_directory(directory=data_dir,target_size=(img_width,img_heigth),
                                class_mode='categorical', subset='validation')

local_weights_path = '/kaggle/input/vgg16/tensorflow2/default/1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5'

base_model = VGG16(weights=local_weights_path, input_shape=(img_width, img_heigth, 3), include_top=False)
model=Sequential()

model.add(base_model)
for layer in base_model.layers:
    layer.trainable=False

model.add(Flatten())
model.add(Dense(1024,activation='relu'))
model.add(Dense(9,activation='sigmoid'))

model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

model.fit(train_datagenerator,epochs=10,validation_data=test_datagenerator)
# Out:
# Found 1329 images belonging to 9 classes.
# Found 329 images belonging to 9 classes.
# Epoch 1/10
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 118s 2s/step - accuracy: 0.3010 - loss: 1.9039 - val_accuracy: 0.6596 - val_loss: 1.1132
# Epoch 2/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.6686 - loss: 1.0949 - val_accuracy: 0.7416 - val_loss: 0.8429
# Epoch 3/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 109s 2s/step - accuracy: 0.7290 - loss: 0.8877 - val_accuracy: 0.7477 - val_loss: 0.7464
# Epoch 4/10
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.7583 - loss: 0.7229 - val_accuracy: 0.8146 - val_loss: 0.6142
# Epoch 5/10
# ...

# %%
model.save('date_fruit_tf_model6.h5')

# %% [markdown]
# ### Conclusion

# %% [markdown]
# We turned the file paths of the date fruit images obtained from Kaggle.com into a DataFrame with the help of the Pandas and OS libraries. Then, we sequentially read all the images using the OpenCV library and normalized them for easier processing. Afterward, we trained our model using Keras deep learning. As a second step, we used the VGG16 model by feeding our data into it, training the pre-trained model with our data, and making it suitable for our purpose. Both methods can be used for Image Classification, but since training a model from scratch is a time-consuming process, the common approach is to use a pre-trained model and apply transfer learning.
